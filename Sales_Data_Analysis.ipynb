# %% [markdown]
# # 💰 Sales Data Analysis using Python Pandas
#
# In this project, we will perform Sales Data Analysis using Python and the Pandas library on a Sales Dataset. The dataset contains information related to products, revenue, quantity sold, payment methods, cities, managers, and sales dates.
#
# The main objective of this project is to understand how real-world sales data can be analyzed using Python. We will perform various operations like data cleaning, handling duplicate records, grouping data, statistical analysis, date-time analysis, visualization, and extracting meaningful business insights from the dataset.
#
# Using different Pandas functions and visualization libraries, we will analyze the dataset step by step and solve multiple real-time questions related to sales performance and revenue analysis. This project also helps in understanding how Python is used in Data Science and Data Analytics for handling and analyzing structured business datasets efficiently.
#
# ## Tools & Libraries Used
#
# - Python
# - Pandas
# - Matplotlib
# - Jupyter Notebook
#
# ## Pandas Functions & Methods Used
#
# - `reset_index()`
# - `loc[]`
# - `info()`
# - `drop()`
# - `str.strip().str.replace()`
# - `duplicated()`
# - `drop_duplicates()`
# - `round()`
# - `pd.to_datetime()`
# - `groupby()`
# - `std()`
# - `var()`
# - `mean()`
# - `agg()`
# - `head()`
# - `columns`
# - `unique()`
# - `nunique()`
# - `describe()`
# - `astype()`
# - `dtype`
# - `value_counts()`
# - `plot(kind='bar')`
# - `sort_values()`
# - `dt.month`
#
# ## Operations Performed
#
# - Data Cleaning
# - Removing Duplicate Records
# - Revenue Analysis
# - Product-wise Analysis
# - Payment Method Analysis
# - City-wise Revenue Analysis
# - Manager-wise Revenue Analysis
# - Date-Time Analysis
# - Statistical Analysis
# - Data Visualization
# - Exploratory Data Analysis (EDA)
#
# ## Questions Solved in this Project
#
# 1. Find the most preferred payment method.
# 2. Find the most selling product:
#    - By Quantity
#    - By Revenue
# 3. Find:
#    - City with maximum revenue
#    - Manager with maximum revenue
# 4. Show date-wise revenue.
# 5. Find the average revenue.
# 6. Find the average revenue of November and December.
# 7. Find the standard deviation of Revenue and Quantity.
# 8. Find the variance of Revenue and Quantity.
# 9. Analyze whether revenue was increasing or decreasing over time.
# 10. Find the average Quantity Sold and average Revenue for each product.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\DELL\Downloads\Sales_Data.csv")

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1  Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0           NaN   Order ID        Date             Product      Price
# 1           NaN      10452   11/7/2022               Fries       3.49
# 2           NaN      10453   11/7/2022           Beverages       2.95
# 3           NaN      10454   11/7/2022       Sides & Other       4.99
# 4           NaN      10455   11/8/2022             Burgers      12.99
# ..          ...        ...         ...                 ...        ...
# 250         NaN      10709  12/28/2022       Sides & Other       4.99
# 251         NaN      10710  12/29/2022             Burgers      12.99
# 252         NaN      10711  12/29/2022  Chicken Sandwiches       9.95
# 253         NaN      10712  12/29/2022               Fries       3.49
# 254         NaN      10713  12/29/2022           Beverages       2.95
#
#     Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  255 non-null    str
#  2   Unnamed: 2  255 non-null    str
#  3   Unnamed: 3  255 non-null    str
#  4   Unnamed: 4  255 non-null    str
#  5   Unnamed: 5  255 non-null    str
#  6   Unnamed: 6  255 non-null    str
#  7   Unnamed: 7  255 non-null    str
#  8   Unnamed: 8  255 non-null    str
#  9   Unnamed: 9  255 non-null    str
# dtypes: float64(1), str(9)
# memory usage: 20.1 KB

# %% [markdown]
# ## Drop unwanted column

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data.head()
# Out:
#   Unnamed: 1 Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5     Unnamed: 6  \
# 0   Order ID       Date        Product      Price   Quantity  Purchase Type
# 1      10452  11/7/2022          Fries       3.49     573.07        Online
# 2      10453  11/7/2022      Beverages       2.95     745.76        Online
# 3      10454  11/7/2022  Sides & Other       4.99     200.40      In-store
# 4      10455  11/8/2022        Burgers      12.99     569.67      In-store
#
#        Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0  Payment Method             Manager       City
# 1       Gift Card    Tom      Jackson     London
# 2       Gift Card         Pablo Perez     Madrid
# 3       Gift Card       Joao    Silva     Lisbon
# 4     Credit Card       Walter Muller     Berlin

# %% [markdown]
# ## Changing column names

# %%
data.loc[0]
# Out:
# Unnamed: 1          Order ID
# Unnamed: 2              Date
# Unnamed: 3           Product
# Unnamed: 4             Price
# Unnamed: 5          Quantity
# Unnamed: 6     Purchase Type
# Unnamed: 7    Payment Method
# Unnamed: 8           Manager
# Unnamed: 9              City
# Name: 0, dtype: str

# %%
data.columns = data.loc[0]

# %%
data.head()
# Out:
# 0  Order ID       Date        Product  Price  Quantity  Purchase Type  \
# 0  Order ID       Date        Product  Price  Quantity  Purchase Type
# 1     10452  11/7/2022          Fries   3.49    573.07        Online
# 2     10453  11/7/2022      Beverages   2.95    745.76        Online
# 3     10454  11/7/2022  Sides & Other   4.99    200.40      In-store
# 4     10455  11/8/2022        Burgers  12.99    569.67      In-store
#
# 0  Payment Method             Manager    City
# 0  Payment Method             Manager    City
# 1       Gift Card    Tom      Jackson  London
# 2       Gift Card         Pablo Perez  Madrid
# 3       Gift Card       Joao    Silva  Lisbon
# 4     Credit Card       Walter Muller  Berlin

# %% [markdown]
# ## Drop the unwanted 1st row

# %%
data.drop(0, inplace=True)

# %%
data
# Out:
# 0   Order ID        Date             Product  Price Quantity Purchase Type  \
# 1      10452   11/7/2022               Fries   3.49   573.07       Online
# 2      10453   11/7/2022           Beverages   2.95   745.76       Online
# 3      10454   11/7/2022       Sides & Other   4.99   200.40     In-store
# 4      10455   11/8/2022             Burgers  12.99   569.67     In-store
# 5      10456   11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
# ..       ...         ...                 ...    ...      ...           ...
# 250    10709  12/28/2022       Sides & Other   4.99   200.40   Drive-thru
# 251    10710  12/29/2022             Burgers  12.99   754.43   Drive-thru
# 252    10711  12/29/2022  Chicken Sandwiches   9.95   281.41   Drive-thru
# 253    10712  12/29/2022               Fries   3.49   630.37   Drive-thru
# 254    10713  12/29/2022           Beverages   2.95   677.97   Drive-thru
#
# 0   Payment Method             Manager    City
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 254 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    str
#  1   Date            254 non-null    str
#  2   Product         254 non-null    str
#  3   Price           254 non-null    str
#  4   Quantity        254 non-null    str
#  5   Purchase Type   254 non-null    str
#  6   Payment Method  254 non-null    str
#  7   Manager         254 non-null    str
#  8   City            254 non-null    str
# dtypes: str(9)
# memory usage: 18.0 KB

# %% [markdown]
# ## Consider the Manager column

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price Quantity Purchase Type  \
# 1    10452  11/7/2022               Fries   3.49   573.07       Online
# 2    10453  11/7/2022           Beverages   2.95   745.76       Online
# 3    10454  11/7/2022       Sides & Other   4.99   200.40     In-store
# 4    10455  11/8/2022             Burgers  12.99   569.67     In-store
# 5    10456  11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
#
# 0 Payment Method             Manager    City
# 1      Gift Card    Tom      Jackson  London
# 2      Gift Card         Pablo Perez  Madrid
# 3      Gift Card       Joao    Silva  Lisbon
# 4    Credit Card       Walter Muller  Berlin
# 5    Credit Card       Walter Muller  Berlin

# %%
data.Manager
# Out:
# 1        Tom      Jackson
# 2             Pablo Perez
# 3           Joao    Silva
# 4           Walter Muller
# 5           Walter Muller
#               ...
# 250         Walter Muller
# 251         Walter Muller
# 252         Walter Muller
# 253         Walter Muller
# 254         Walter Muller
# Name: Manager, Length: 254, dtype: str

# %%
data.Manager.unique()
# Out:
# <StringArray>
# [  'Tom      Jackson', '       Pablo Perez',      'Joao    Silva',
#       'Walter Muller',      'Remy    Monet',         'Remy Monet',
#   '       Remy Monet',     'Remy     Monet',        'Pablo Perez',
#       'Pablo   Perez',       'Pablo  Perez',     'Pablo    Perez',
#          'Joao Silva',        'Tom Jackson']
# Length: 14, dtype: str

# %%
data.Manager.nunique()
# Out:
# 14

# %%
data['Manager'] = data['Manager'].str.strip().str.replace(r'\s+',' ', regex=True)

# %%
data.head(20)
# Out:
# 0  Order ID        Date             Product  Price Quantity Purchase Type  \
# 1     10452   11/7/2022               Fries   3.49   573.07       Online
# 2     10453   11/7/2022           Beverages   2.95   745.76       Online
# 3     10454   11/7/2022       Sides & Other   4.99   200.40     In-store
# 4     10455   11/8/2022             Burgers  12.99   569.67     In-store
# 5     10456   11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
# 6     10457   11/8/2022               Fries   3.49   573.07     In-store
# 7     10459   11/8/2022       Sides & Other   4.99   200.40     In-store
# 8     10460   11/9/2022             Burgers  12.99   554.27     In-store
# 9     10461   11/9/2022  Chicken Sandwiches   9.95   201.01     In-store
# 10    10462   11/9/2022               Fries   3.49   573.07     In-store
# 11    10463   11/9/2022           Beverages   2.95   677.97     In-store
# 12    10464   11/9/2022       Sides & Other   4.99   200.40     In-store
# ...

# %%
data['Manager'].unique()
# Out:
# <StringArray>
# ['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller', 'Remy Monet']
# Length: 5, dtype: str

# %%
data['Manager'].nunique()
# Out:
# 5

# %% [markdown]
# ## Removing the duplicate records

# %%
data.head()
# Out:
# 0 Order ID       Date             Product  Price Quantity Purchase Type  \
# 1    10452  11/7/2022               Fries   3.49   573.07       Online
# 2    10453  11/7/2022           Beverages   2.95   745.76       Online
# 3    10454  11/7/2022       Sides & Other   4.99   200.40     In-store
# 4    10455  11/8/2022             Burgers  12.99   569.67     In-store
# 5    10456  11/8/2022  Chicken Sandwiches   9.95   201.01     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data.describe()
# Out:
# 0      Order ID       Date  Product  Price Quantity Purchase Type  \
# count       254        254      254    254      254           254
# unique      254         53        5      7       29             3
# top       10452  11/9/2022  Burgers  12.99   200.40       Online
# freq          1          5       52     52       49           107
#
# 0      Payment Method      Manager    City
# count             254          254     254
# unique              3            5       5
# top       Credit Card  Tom Jackson  London
# freq              120           75      75

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.drop_duplicates(inplace=True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.describe()
# Out:
# 0      Order ID       Date  Product  Price Quantity Purchase Type  \
# count       254        254      254    254      254           254
# unique      254         53        5      7       29             3
# top       10452  11/9/2022  Burgers  12.99   200.40       Online
# freq          1          5       52     52       49           107
#
# 0      Payment Method      Manager    City
# count             254          254     254
# unique              3            5       5
# top       Credit Card  Tom Jackson  London
# freq              120           75      75

# %%
data[data['Order ID'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data[data['Order ID'] == 10483]
# Out:
# Empty DataFrame
# Columns: [Order ID, Date, Product, Price, Quantity, Purchase Type, Payment Method, Manager, City]
# Index: []

# %%
data.drop(32,inplace=True)

# %% [markdown]
# ## Converting the datatype of columns

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    str
#  1   Date            253 non-null    str
#  2   Product         253 non-null    str
#  3   Price           253 non-null    str
#  4   Quantity        253 non-null    str
#  5   Purchase Type   253 non-null    str
#  6   Payment Method  253 non-null    str
#  7   Manager         253 non-null    str
#  8   City            253 non-null    str
# dtypes: str(9)
# memory usage: 19.8 KB

# %%
data.Quantity = data.Quantity.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    str
#  1   Date            253 non-null    str
#  2   Product         253 non-null    str
#  3   Price           253 non-null    str
#  4   Quantity        253 non-null    float64
#  5   Purchase Type   253 non-null    str
#  6   Payment Method  253 non-null    str
#  7   Manager         253 non-null    str
#  8   City            253 non-null    str
# dtypes: float64(1), str(8)
# memory usage: 19.8 KB

# %%
data.Quantity = data.Quantity.round()

# %%
data.Quantity
# Out:
# 1      573.0
# 2      746.0
# 3      200.0
# 4      570.0
# 5      201.0
#        ...
# 250    200.0
# 251    754.0
# 252    281.0
# 253    630.0
# 254    678.0
# Name: Quantity, Length: 253, dtype: float64

# %%
data.Quantity = data.Quantity.astype(int)

# %%
data['Quantity']
# Out:
# 1      573
# 2      746
# 3      200
# 4      570
# 5      201
#       ...
# 250    200
# 251    754
# 252    281
# 253    630
# 254    678
# Name: Quantity, Length: 253, dtype: int64

# %%
data['Order ID'] = data['Order ID'].astype(int)
data['Price'] = data['Price'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    int64
#  1   Date            253 non-null    str
#  2   Product         253 non-null    str
#  3   Price           253 non-null    float64
#  4   Quantity        253 non-null    int64
#  5   Purchase Type   253 non-null    str
#  6   Payment Method  253 non-null    str
#  7   Manager         253 non-null    str
#  8   City            253 non-null    str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 19.8 KB

# %%
data.Date = pd.to_datetime(data.Date)

# %%
data.Date.dtype
# Out:
# dtype('<M8[us]')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    int64
#  1   Date            253 non-null    datetime64[us]
#  2   Product         253 non-null    str
#  3   Price           253 non-null    float64
#  4   Quantity        253 non-null    int64
#  5   Purchase Type   253 non-null    str
#  6   Payment Method  253 non-null    str
#  7   Manager         253 non-null    str
#  8   City            253 non-null    str
# dtypes: datetime64[us](1), float64(1), int64(2), str(5)
# memory usage: 19.8 KB

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City
# ...

# %% [markdown]
# ## Analyzing the Data
#
# ## 1) What was the Most Preferred Payment Method ?

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data['Payment Method'].unique()
# Out:
# <StringArray>
# [' Gift Card', ' Credit Card', ' Cash']
# Length: 3, dtype: str

# %%
data['Payment Method'].nunique()
# Out:
# 3

# %%
data['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card    119
# Cash            76
# Gift Card       58
# Name: count, dtype: int64

# %%
data['Payment Method'].value_counts(normalize=True)*100
# Out:
# Payment Method
# Credit Card    47.035573
# Cash           30.039526
# Gift Card      22.924901
# Name: proportion, dtype: float64

# %%
data['Payment Method'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment Method'>

# %% [markdown]
# ## 2) Which one was the Most Selling Product
# ##       By Quantity
# ##       By Revenue

# %% [markdown]
# ## By Quantity

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data.groupby('Product')['Quantity'].sum()
# Out:
# Product
# Beverages             34310
# Burgers               29018
# Chicken Sandwiches    11133
# Fries                 32023
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Product
# Beverages             34310
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
most_quantity = data.groupby('Product')['Quantity'].sum().sort_values(ascending=False)
most_quantity
# Out:
# Product
# Beverages             34310
# Fries                 32023
# Burgers               29018
# Chicken Sandwiches    11133
# Sides & Other          9800
# Name: Quantity, dtype: int64

# %%
type(most_quantity)
# Out:
# pandas.Series

# %%
most_quantity = most_quantity.reset_index()
most_quantity
# Out:
#    index             Product  Quantity
# 0      0           Beverages     34310
# 1      1               Fries     32023
# 2      2             Burgers     29018
# 3      3  Chicken Sandwiches     11133
# 4      4       Sides & Other      9800

# %%
type(most_quantity)
# Out:
# pandas.DataFrame

# %%
plt.figure(figsize=(9,4))
plt.bar(most_quantity['Product'], most_quantity['Quantity'],color=['red','black','green','yellow','cyan'],width=0.4)
plt.title("Most Selling Product - By Quantity")
plt.xlabel("Product")
plt.ylabel("Quantity")
# Out:
# Text(0, 0.5, 'Quantity')

# %% [markdown]
# ## By Revenue

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City
# 1      Gift Card    Tom Jackson  London
# 2      Gift Card    Pablo Perez  Madrid
# 3      Gift Card     Joao Silva  Lisbon
# 4    Credit Card  Walter Muller  Berlin
# 5    Credit Card  Walter Muller  Berlin

# %%
data['Revenue']=data['Price']*data['Quantity']

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue
# ...

# %%
data.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             101214.50
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
most_revenue = data.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
most_revenue
# Out:
# Product
# Burgers               376943.82
# Fries                 125626.57
# Chicken Sandwiches    114612.45
# Beverages             101214.50
# Sides & Other          48902.00
# Name: Revenue, dtype: float64

# %%
most_revenue = most_revenue.reset_index()
most_revenue
# Out:
#    index             Product    Revenue
# 0      0             Burgers  376943.82
# 1      1               Fries  125626.57
# 2      2  Chicken Sandwiches  114612.45
# 3      3           Beverages  101214.50
# 4      4       Sides & Other   48902.00

# %%
plt.figure(figsize=(9,4))
plt.bar(most_revenue['Product'], most_revenue['Revenue'],color=['red','black','green','yellow','cyan'],width=0.4)
plt.title("Most Selling Product - By Revenue")
plt.xlabel("Product")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# ## 3) Which City had maximum revenue, or, Which Manager earned maximum revenue ?

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue
# ...

# %%
data.City.unique()
# Out:
# <StringArray>
# ['London', 'Madrid', 'Lisbon', 'Berlin', 'Paris']
# Length: 5, dtype: str

# %%
data.City.nunique()
# Out:
# 5

# %%
data.groupby('City')['Revenue'].sum().sort_values(ascending=False)
# Out:
# City
# Lisbon    239635.39
# London    211160.04
# Madrid    136154.24
# Berlin    100572.34
# Paris      79777.33
# Name: Revenue, dtype: float64

# %%
data.Manager.unique()
# Out:
# <StringArray>
# ['Tom Jackson', 'Pablo Perez', 'Joao Silva', 'Walter Muller', 'Remy Monet']
# Length: 5, dtype: str

# %%
data.Manager.nunique()
# Out:
# 5

# %%
data.groupby('Manager')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Manager
# Joao Silva       239635.39
# Tom Jackson      211160.04
# Pablo Perez      136154.24
# Walter Muller    100572.34
# Remy Monet        79777.33
# Name: Revenue, dtype: float64

# %% [markdown]
# ## 4) Show the Date wise revenue.

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data.Date.dtype
# Out:
# dtype('<M8[us]')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 253 entries, 1 to 254
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        253 non-null    int64
#  1   Date            253 non-null    datetime64[us]
#  2   Product         253 non-null    str
#  3   Price           253 non-null    float64
#  4   Quantity        253 non-null    int64
#  5   Purchase Type   253 non-null    str
#  6   Payment Method  253 non-null    str
#  7   Manager         253 non-null    str
#  8   City            253 non-null    str
#  9   Revenue         253 non-null    float64
# dtypes: datetime64[us](1), float64(2), int64(2), str(5)
# memory usage: 21.7 KB

# %%
data.plot('Date','Revenue',color='red',linewidth=2,figsize=(9,4))
plt.title("Date wise Revenue")
plt.xlabel("Date")
plt.ylabel("Revenue")
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# ## 5) What was the Average Revenue ?

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data['Revenue'].mean()
# Out:
# np.float64(3032.8037154150197)

# %% [markdown]
# ## 6) What was the Average Revenue of November & December month ?

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue
# 1      Gift Card    Tom Jackson  London  1999.77
# 2      Gift Card    Pablo Perez  Madrid  2200.70
# 3      Gift Card     Joao Silva  Lisbon   998.00
# 4    Credit Card  Walter Muller  Berlin  7404.30
# 5    Credit Card  Walter Muller  Berlin  1999.95

# %%
data['Month'] = data['Date'].dt.month

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11=data[data['Month']==11]
m11
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 109     10568 2022-11-30           Beverages   2.95       678       Online
# 110     10569 2022-11-30       Sides & Other   4.99       200       Online
# 128     10537 2022-11-24               Fries   3.49       630   Drive-thru
# 129     10538 2022-11-24           Beverages   2.95       746   Drive-thru
# 130     10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11.Revenue.mean()
# Out:
# np.float64(2946.562678571429)

# %%
m12=data[data['Month']==12]
m12
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111     10570 2022-12-01             Burgers  12.99       493       Online
# 112     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 113     10572 2022-12-01               Fries   3.49       573       Online
# 114     10573 2022-12-01           Beverages   2.95       678       Online
# 115     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
m12.Revenue.mean()
# Out:
# np.float64(3101.3072340425533)

# %% [markdown]
# ## 7) What was the  Standard Deviation of Revenue and Quantity ?

# %%
data['Quantity'].std()
# Out:
# np.float64(214.96756467336496)

# %%
data['Revenue'].std()
# Out:
# np.float64(2423.8598403575334)

# %% [markdown]
# ## 8) What was the Variance of Revenue and Quantity ?

# %%
data['Quantity'].var()
# Out:
# np.float64(46211.05386159734)

# %%
data['Revenue'].var()
# Out:
# np.float64(5875096.525698046)

# %% [markdown]
# ## 9) Was the revenue increasing or decreasing over the time?

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
m11=data[data.Month==11]
m11
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 2       10453 2022-11-07           Beverages   2.95       746       Online
# 3       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4       10455 2022-11-08             Burgers  12.99       570     In-store
# 5       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 109     10568 2022-11-30           Beverages   2.95       678       Online
# 110     10569 2022-11-30       Sides & Other   4.99       200       Online
# 128     10537 2022-11-24               Fries   3.49       630   Drive-thru
# 129     10538 2022-11-24           Beverages   2.95       746   Drive-thru
# 130     10539 2022-11-24       Sides & Other   4.99       200   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
m11.Revenue.sum()
# Out:
# np.float64(330015.02)

# %%
m12=data[data.Month==12]
m12
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 111     10570 2022-12-01             Burgers  12.99       493       Online
# 112     10571 2022-12-01  Chicken Sandwiches   9.95       201       Online
# 113     10572 2022-12-01               Fries   3.49       573       Online
# 114     10573 2022-12-01           Beverages   2.95       678       Online
# 115     10574 2022-12-01       Sides & Other   4.99       200       Online
# ..        ...        ...                 ...    ...       ...           ...
# 250     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 251     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 252     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 253     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 254     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City  Revenue  Month
# ...

# %%
m12.Revenue.sum()
# Out:
# np.float64(437284.32)

# %% [markdown]
# ## 10) What was the Average 'Quantity Sold' & 'Average Revenue' for each product ?

# %%
data.head()
# Out:
# 0  Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1     10452 2022-11-07               Fries   3.49       573       Online
# 2     10453 2022-11-07           Beverages   2.95       746       Online
# 3     10454 2022-11-07       Sides & Other   4.99       200     In-store
# 4     10455 2022-11-08             Burgers  12.99       570     In-store
# 5     10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
#
# 0 Payment Method        Manager    City  Revenue  Month
# 1      Gift Card    Tom Jackson  London  1999.77     11
# 2      Gift Card    Pablo Perez  Madrid  2200.70     11
# 3      Gift Card     Joao Silva  Lisbon   998.00     11
# 4    Credit Card  Walter Muller  Berlin  7404.30     11
# 5    Credit Card  Walter Muller  Berlin  1999.95     11

# %%
data.groupby('Product')[['Quantity', 'Revenue']].agg({
    'Quantity': 'mean',
    'Revenue': 'mean'
})
# Out:
# 0                     Quantity      Revenue
# Product
# Beverages           700.204082  2065.602041
# Burgers             558.038462  7248.919615
# Chicken Sandwiches  214.096154  2204.085577
# Fries               627.901961  2463.266078
# Sides & Other       200.000000   998.000000
